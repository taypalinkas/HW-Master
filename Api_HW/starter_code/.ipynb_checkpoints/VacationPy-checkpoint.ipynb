# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !jupyter nbextension enable --py gmaps
# Out:
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: OK

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_py = pd.read_csv(
    "weather_py.csv", dtype="object", encoding="utf-8")
len(weather_py)
weather_py
# Out:
#            City     Lat     Lng Max_Temp Humidity Cloudiness Wind_Speed  \
# 0      Coquimbo  -29.95  -71.34   287.15       87          0        1.5
# 1     Jamestown    42.1  -79.24   273.71       84         90        2.1
# 2     Saskylakh   71.92  114.08   260.21       88          0       2.23
# 3     Cape Town  -33.93   18.42   281.15       87         55        1.0
# 4         Bluff   -46.6  168.33   287.59       54         47       2.24
# ..          ...     ...     ...      ...      ...        ...        ...
# 568       Jatai  -17.88  -51.71   291.27       76         12       2.85
# 569      Narsaq   60.92  -46.05   271.15       63         69        4.1
# 570        Hofn   64.25  -15.21   278.84       83        100       4.47
# 571  Natitingou    10.3    1.38   300.15       83         95       4.06
# 572    Blatnica   44.49   17.82   279.15       93         38        1.0
#
#     Country        Date
# 0        CL  1587182354
# 1        US  1587182354
# 2        RU  1587182354
# 3        ZA  1587182270
# 4        NZ  1587182355
# ..      ...         ...
# 568      BR  1587182521
# 569      GL  1587182521
# 570      IS  1587182522
# 571      BJ  1587182522
# 572      BA  1587182522
#
# [573 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
weather_py = weather_py.dropna()
locations = weather_py[["Lat", "Lng"]].astype(float)
humid = weather_py["Humidity"].astype(float)

# %%
gmaps.configure(api_key=g_key)
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humid, 
                                 dissipating=False, max_intensity=100,point_radius=3)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
weather_py = weather_py.dropna()

# A max temperature lower than 80 degrees but higher than 70.

weather_py["Max_Temp"] = weather_py["Max_Temp"].astype(float)
weather_py = weather_py[weather_py["Max_Temp"] > 294.26]
weather_py = weather_py[weather_py["Max_Temp"] < 299.82]

# wind speed less than 10 mph.

weather_py["Wind_Speed"] = weather_py["Wind_Speed"].astype(float)
weather_py = weather_py[weather_py["Wind_Speed"] < 4.47]

#Zero cloudiness.

weather_py["Cloudiness"] = weather_py["Cloudiness"].astype(float)
weather_py = weather_py[weather_py["Cloudiness"] == 0]
hotel_df = weather_py

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
target_coordinates = "-34.58, 150.86" # coordinates of one of my cities
target_radius = 5000
target_type = "lodging"

# find the closest hotel of each type to coordinates

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": target_coordinates,
    "rankby": "distance",
    "type": target_type,
    "key": g_key,
}

response = requests.get(base_url,params=params).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCHgEAAA7_mJZjOSoUlGpxbhO6lZcizAQbKHEliXfB5R_2DkByf4OKtlAx2nPenIlsHMra2KSjM41U4vtpJ0pBPfjnjEBF7lME8WWAwBbuW4NrHMqxtWy3M3fzbrN5yTpNHMBlwJPhyczbvGMFarLO5pjQ0cmmU2n7Ba-_ctvUtG9A62iiLcwfPYiQkQ0-u5HRvf4g8u0Osd_DB_49a12dsCQFPhrFO5Bqap75yMdCDGNurp63i5j4e9YPNJbBu6fjWggmXq0roxveXL73OoLoW3CR4mSXwzNhOEwQYGx1E0T3wUT0ChvhV9qPTxT7qz1fjmuERKnBZY1t5cRZ6EG6Atjv1xD25BYvX6vK83orUXmwPjqikCEeWKQrOJrIoF1HLlqDnxIQob6d-b30PaxkFS7NvR_1kBoUDc6pT68F1qAV6iyrS1giGOiSVJc",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.5817679,
#                     "lng": 150.8651719
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5803274197085,
#                         "lng": 150.8664781802915
#                     },
#                     "southwest": {
#                         "lat": -34.5830253802915,
#                         "lng": 150.8637802197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "9691a649c8933e90f6ae1b51196c1dde19751cdb",
#             "name": "Shellharbour Village Escape",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112081544920397288569\">Shellharbour Village Escape</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAAskyOGEHYm32eQqJpKBAThN3jlP5Ja9KTLJqeCiuTaqTAbKkGoZfJXjpfei5ntgvV8ZuxckrbL_MAfNo9qLH578Rcdsur7ATxUaxR23uloNVTREoJA2PTZxVLz_f9ZSvEhBcokdVA2pCSPDn7wiJbOf8GhTH8l6bDt2SWJu669woP6gb-pgvZw",
#                     "width": 2448
#                 }
#             ],
#             "place_id": "ChIJEa3xoYMUE2sRQeYpb7nfP-I",
#             "plus_code": {
#                 "compound_code": "CV98+73 Shellharbour, New South Wales, Australia",
#                 "global_code": "4RQGCV98+73"
#             },
#             "rating": 5,
#             "reference": "ChIJEa3xoYMUE2sRQeYpb7nfP-I",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "9 Robertson Street, Shellharbour"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.5788323,
#                     "lng": 150.8666606
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5775456697085,
#                         "lng": 150.8678222802915
#                     },
#                     "southwest": {
#                         "lat": -34.5802436302915,
#                         "lng": 150.8651243197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "6e87e125928e6039d40df047268576b40dc0c374",
#             "name": "Shellharbour Village Motel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1365,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106187074773863791931\">Shellharbour Village Motel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAMW0HX3aeeCTm62M5gt7zXMA0hYzuGf7It2Epxr7mNm781xa2IJMXW_96VAPRySk3rfjLX7M1RwSJoKg3RdH_ad8kkRnAmMKiI3Dj3DL9kqZx09YklXQjk75niu_hadzEEhB3FdHd4_SvoaBhn4mNj0O_GhRMMuE8caarvB2_X6m-hVzC5yD6Sw",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJPT3tSoEUE2sRs50f-QKAKY0",
#             "plus_code": {
#                 "compound_code": "CVC8+FM Shellharbour, New South Wales, Australia",
#                 "global_code": "4RQGCVC8+FM"
#             },
#             "rating": 4.2,
#             "reference": "ChIJPT3tSoEUE2sRs50f-QKAKY0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 89,
#             "vicinity": "28 Mary Street, Shellharbour"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.5798309,
#                     "lng": 150.8671865
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5784832697085,
#                         "lng": 150.8685361802915
#                     },
#                     "southwest": {
#                         "lat": -34.5811812302915,
#                         "lng": 150.8658382197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "7b1bcb911cc7e83178c12aa72d27f7496417d701",
#             "name": "2 Allens Lane",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107852637522036807635\">Hetty Cummins</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAkWZbvoNIAs_M0zFBdMywCIYmFOHZcMjtwrNxU2gCEgBSAnK96XhyRRlJWCQkmsxr9nojA-09hnokPKPL_8MYcNSWaTBR7IhDb-ZNic-VbTIJN-2dyr7DYzY46GrD9d6IEhApg-Hl36M9oa32ajOEkV-AGhQcca_qAfIh2kXe1ACOnNtnA0GDaw",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ4UEbJQYVE2sRjAlI2Ug3xmU",
#             "plus_code": {
#                 "compound_code": "CVC8+3V Shellharbour, New South Wales, Australia",
#                 "global_code": "4RQGCVC8+3V"
#             },
#             "reference": "ChIJ4UEbJQYVE2sRjAlI2Ug3xmU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "2 Allens Lane, Shellharbour"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.573031,
#                     "lng": 150.862409
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5721289197085,
#                         "lng": 150.8638484802915
#                     },
#                     "southwest": {
#                         "lat": -34.5748268802915,
#                         "lng": 150.8611505197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "2e4a1c0004a04507c9d9038bcd65c47e4c623fc8",
#             "name": "Shellharbour Resort & Conference Centre",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104257514568729953436\">F Laimo</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAnDFOw7tuAmn7MjNYZ4Qk0qE61xXsWZ9KbTqXOtR_gStU5zwEF6KrjnVww1LBdQ753gQQ21YkiZQMdb-zZUQPooqdvamFLKNCa7lP_S3bJ-UegANdW0WZ9yv4T6BGZ0oYEhCH5lgQmbaWSG479vDn_t9qGhSA0cxtYI8BnpQO9nhx3oHLtix9lQ",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ9WUH038UE2sRxM0ILqI68cI",
#             "plus_code": {
#                 "compound_code": "CVG6+QX Shellharbour, New South Wales, Australia",
#                 "global_code": "4RQGCVG6+QX"
#             },
#             "rating": 3.6,
#             "reference": "ChIJ9WUH038UE2sRxM0ILqI68cI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 107,
#             "vicinity": "Shellharbour Rd &, Ocean Beach Drive, Shellharbour"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.57605369999999,
#                     "lng": 150.8685457
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5746563197085,
#                         "lng": 150.8700430802915
#                     },
#                     "southwest": {
#                         "lat": -34.57735428029149,
#                         "lng": 150.8673451197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "220f3d35141ef038710a4524f36ad17b1f8a5b67",
#             "name": "The Beach B & B Shellharbour",
#             "place_id": "ChIJVVWxaIcUE2sRTcEiw4ENoHI",
#             "plus_code": {
#                 "compound_code": "CVF9+HC Shellharbour, New South Wales, Australia",
#                 "global_code": "4RQGCVF9+HC"
#             },
#             "rating": 4,
#             "reference": "ChIJVVWxaIcUE2sRTcEiw4ENoHI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "13 Wollongong Street, Shellharbour"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.578576,
#                     "lng": 150.8697951
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5771551697085,
#                         "lng": 150.8711086802915
#                     },
#                     "southwest": {
#                         "lat": -34.5798531302915,
#                         "lng": 150.8684107197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "f572a87f34297eb31b49b4132e3e13c43aabfefe",
#             "name": "Holiday Appartment - Addison St",
#             "photos": [
#                 {
#                     "height": 300,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100613802278316180612\">Holiday Appartment - Addison St</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAVgDUArr8XyVsbolXh2QZ37g1s4k8mQn3PmCChyR4NCU39p17UYH3H19-WUW10k1m2qJVzXMEwGyNrnJMx5-V7oktNL0lE1YD4eCEdFPRrJgE4d3qcE35Ej--D08MznYPEhBV9WjUQXGNHRyU3v4vdZK_GhRUqEXDHeoxcKcpVo8hX5HLYk1hjg",
#                     "width": 400
#                 }
#             ],
#             "place_id": "ChIJYVqPV4YUE2sRcPMoDvlHo2g",
#             "plus_code": {
#                 "compound_code": "CVC9+HW Shellharbour, New South Wales, Australia",
#                 "global_code": "4RQGCVC9+HW"
#             },
#             "rating": 5,
#             "reference": "ChIJYVqPV4YUE2sRcPMoDvlHo2g",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "3/9 Addison Street, Shellharbour"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.5755336,
#                     "lng": 150.8689462
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5742292697085,
#                         "lng": 150.8701621802915
#                     },
#                     "southwest": {
#                         "lat": -34.5769272302915,
#                         "lng": 150.8674642197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "5660ccc96aa8be44f76d78a4250f7ecbe168301f",
#             "name": "Shellharbour Village Beach House",
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103501407534714054305\">paul mcnulty</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAjUt6I5a2fstoS7sAy0c_kStngY0qS-VjqSqcvybb0tSOpUHICXPJJdoDVkKVFa8gWPQL0g7ICWho1ceqy-vMD8NWQbgZMvpfgnDBs7aHfloA6XQB_-rLBD9_39hlRypyEhC8WbcDjDpUIaun6697veV3GhS6imVHXKFrNIQR5pYcV_RrLGfA0Q",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJw_d3h30UE2sR9wj8qI3S6Uw",
#             "plus_code": {
#                 "compound_code": "CVF9+QH Shellharbour, New South Wales, Australia",
#                 "global_code": "4RQGCVF9+QH"
#             },
#             "rating": 4,
#             "reference": "ChIJw_d3h30UE2sR9wj8qI3S6Uw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "14 Wollongong Street, Shellharbour"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.580934,
#                     "lng": 150.870823
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5794457197085,
#                         "lng": 150.8721044302915
#                     },
#                     "southwest": {
#                         "lat": -34.5821436802915,
#                         "lng": 150.8694064697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "18eff9007af1730d7bf03f8f18f4f47b670eaaac",
#             "name": "Sweet Spot",
#             "place_id": "ChIJU3ecvWcVE2sRqoaFEnhtRvE",
#             "plus_code": {
#                 "compound_code": "CV9C+J8 Shellharbour, New South Wales, Australia",
#                 "global_code": "4RQGCV9C+J8"
#             },
#             "rating": 5,
#             "reference": "ChIJU3ecvWcVE2sRqoaFEnhtRvE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "7 Darley Street, Shellharbour"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.579889,
#                     "lng": 150.871144
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5784240197085,
#                         "lng": 150.8724340802915
#                     },
#                     "southwest": {
#                         "lat": -34.5811219802915,
#                         "lng": 150.8697361197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d462a69b62f093c22dbb6484e1eaa336516f47f6",
#             "name": "Pelicans Rest Shellharbour",
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103094134577138516249\">Pelicans Rest Shellharbour</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAw3Y3swx-whllo8-hoygyTir5gLJ8mI4KKy_gwj4UWw2iG8xhY7D1nvHK03548VSivZq-Pe5X-N1moUevqabbc9zGKp_JqDN94if-s0P2FWG3czA4vPRDqrGiI6WaVyJQEhAjX7mZ0IeUXNAaB_oCIzfhGhRHhX28-DPOYhFJy3IWY6dPL96J4w",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJ2ehaFYYUE2sRuym-URUtLFU",
#             "plus_code": {
#                 "compound_code": "CVCC+2F Shellharbour, New South Wales, Australia",
#                 "global_code": "4RQGCVCC+2F"
#             },
#             "rating": 4.9,
#             "reference": "ChIJ2ehaFYYUE2sRuym-URUtLFU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 9,
#             "vicinity": "7 Boollwarroo Parade, Shellharbour"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.5807979,
#                     "lng": 150.8711314
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5793243197085,
#                         "lng": 150.8724175802915
#                     },
#                     "southwest": {
#                         "lat": -34.5820222802915,
#                         "lng": 150.8697196197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "9479083a808007a2ea6cb69df7bbc3874d891cd3",
#             "name": "Dream Catcher Beach House",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 706,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110534215360574330725\">John White</a>"
#                     ],
#                     "photo_reference": "CmRZAAAAEakTup1Ea-c80yqMEpGyPgGF0YwWoszCXmT66PAb-Q8tPu2dxhFvjFhL1Fbg59V-3L3NnmEDC9C9CFdKGhTF19-FB4NXXCz76j6E32xNToCOtue_85gugfha4iVtqq2GEhCfX1OAmVFIqbRU88Rn8Jb5GhTIBnpdFbdS4MzyLbtp8suC-uGQYA",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJDT1UC4YUE2sRI_91VntABXA",
#             "plus_code": {
#                 "compound_code": "CV9C+MF Shellharbour, New South Wales, Australia",
#                 "global_code": "4RQGCV9C+MF"
#             },
#             "rating": 5,
#             "reference": "ChIJDT1UC4YUE2sRI_91VntABXA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "5 Darley Street, Shellharbour"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.58015,
#                     "lng": 150.871371
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.57891791970849,
#                         "lng": 150.8727788802915
#                     },
#                     "southwest": {
#                         "lat": -34.58161588029149,
#                         "lng": 150.8700809197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "e7f13a4ff2105452baf2dd1104d7662e37b3ef3b",
#             "name": "Seahaven Beach House",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 848,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117335062783014426651\">Seahaven Beach House</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAhOFlwuy9wWbmFITrzW61NYIyUhlpiVjpWufYPkN02CvzNeKc4h5dRScI5dMOLp4OhKcGpGkBP2XvFgf3qMLCONpKeWkigSeDxnq63E_tWiKDi7gomw6RQMwzk1xyTQM9EhA6sUFJ-CCO3JhJupPAqXo7GhTcNIAkZ0W_JWUX4kX0TVO0uy0nYQ",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJZ5drFIYUE2sRw4yIxavL7rM",
#             "plus_code": {
#                 "compound_code": "CV9C+WG Shellharbour, New South Wales, Australia",
#                 "global_code": "4RQGCV9C+WG"
#             },
#             "rating": 4.1,
#             "reference": "ChIJZ5drFIYUE2sRw4yIxavL7rM",
#             "scope": "GOOGLE",
#             "types": [
#                 "real_estate_agency",
#                 "travel_agency",
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 7,
#             "vicinity": "8 Darley Street, Shellharbour"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.58015,
#                     "lng": 150.8713711
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5789178697085,
#                         "lng": 150.8727789802915
#                     },
#                     "southwest": {
#                         "lat": -34.5816158302915,
#                         "lng": 150.8700810197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "91a400870f84ce23f85c7c8a7fee5354f622de2e",
#             "name": "Holiday Property Services",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 848,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112045842281836629985\">Holiday Property Services</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA9xgmNaf_TIOxcVIGtcSedf8wbfyfaVWDp6SSW5Qf45MTsOqtXXgbEb8kQh0Yvjlmg5dL3xzRG3xwhIEp41EqHgLHs2-VRm89kuSQ0D5LVeusIvIB4YsJOyU9oaPWtsmsEhBrZFDRjVwMjJCQqGUygM5oGhQMmCbLtWfHojNgTUHEzBwagU5y8w",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJZ5drFIYUE2sRe7MCKIRguo0",
#             "plus_code": {
#                 "compound_code": "CV9C+WG Shellharbour, New South Wales, Australia",
#                 "global_code": "4RQGCV9C+WG"
#             },
#             "rating": 5,
#             "reference": "ChIJZ5drFIYUE2sRe7MCKIRguo0",
#             "scope": "GOOGLE",
#             "types": [
#                 "real_estate_agency",
#                 "travel_agency",
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "8 Darley Street, Shellharbour"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.5804032,
#                     "lng": 150.8719181
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5790603697085,
#                         "lng": 150.8732490802915
#                     },
#                     "southwest": {
#                         "lat": -34.5817583302915,
#                         "lng": 150.8705511197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "5063760f61b4b117d821ba325b07c4428825a244",
#             "name": "Shellharbour Holiday Park",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114515323442011122672\">Robert Ahearn</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAzd2v4MF8Zjfztk_afEH2fv8DHX7QdL-KcGC4t59KFfWlAsEKVBbheLA9qKl3G4suH-NeWgclNOB1al2eRnK9U5dn0VC_NtnxH1qRHUex-Z6YvEBJgedhUvbTvtgJ_sIuEhAPQzEDgYhTn37YMMlA2bWeGhQkfov3uNHsENutf_1x7y9D7Cjl9A",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJyws-9eXwEmsR8F3CtUc5C_Y",
#             "plus_code": {
#                 "compound_code": "CV9C+RQ Shellharbour, New South Wales, Australia",
#                 "global_code": "4RQGCV9C+RQ"
#             },
#             "rating": 4.1,
#             "reference": "ChIJyws-9eXwEmsR8F3CtUc5C_Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "rv_park",
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 61,
#             "vicinity": "1 John Street, Shellharbour"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.5813071,
#                     "lng": 150.8719987
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5799004697085,
#                         "lng": 150.8735163302915
#                     },
#                     "southwest": {
#                         "lat": -34.5825984302915,
#                         "lng": 150.8708183697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "67a395c4c843fc6efdd8d4438ec54d6f5a8bf6c9",
#             "name": "Sea Vista Shellharbour",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 600,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114662925408294264867\">Sea Vista Shellharbour</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAXdJ7AwSwUv23ijNEjuBU97fwHo_MeFX3T-zl1DlV8l7EnhaDpLszKFTBVjZhpNw_lS7t1ffmjH6Q2a_U4a4LjwdzRYcOtjg54AOufK3wPf2drgsZlYMP6VymZnHc_IWwEhA0V8Ni1gvdD5tV0isZXaPtGhStR_AYwifEykTdKBtKou_IT8LXkg",
#                     "width": 800
#                 }
#             ],
#             "place_id": "ChIJN1GNjMsVE2sRdkVfXCdB-VY",
#             "plus_code": {
#                 "compound_code": "CV9C+FQ Shellharbour, New South Wales, Australia",
#                 "global_code": "4RQGCV9C+FQ"
#             },
#             "reference": "ChIJN1GNjMsVE2sRdkVfXCdB-VY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "16 John Street, Shellharbour"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.5814203,
#                     "lng": 150.8721523
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5800274697085,
#                         "lng": 150.8736287302915
#                     },
#                     "southwest": {
#                         "lat": -34.5827254302915,
#                         "lng": 150.8709307697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "ce48bbe518e7f090d7669dc2010e2a1110a3bb8a",
#             "name": "The White House",
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105848687736069815790\">The White House</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAdLwmvmZsJduxcIUypwNb08c02kJj9F7tMvtCpdCLB5HdLAlNTavDxPhx_RGF5E6pqD6mcRzTqVgygc55jssE97F4OIa76wc5Jq_M7n-XIC9c3uf9YXfdIWZsH9Aqr0KOEhA3-7il-CJWoy5kVXsk-cRPGhRTeq7kheHNN6-mJHVteFc-04U3Hg",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJk0FG_oUUE2sR4ZbmjAUHiRg",
#             "plus_code": {
#                 "compound_code": "CV9C+CV Shellharbour, New South Wales, Australia",
#                 "global_code": "4RQGCV9C+CV"
#             },
#             "rating": 4,
#             "reference": "ChIJk0FG_oUUE2sR4ZbmjAUHiRg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "18 John Street, Shellharbour"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.5811518,
#                     "lng": 150.8730665
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5798472197085,
#                         "lng": 150.8743637802915
#                     },
#                     "southwest": {
#                         "lat": -34.5825451802915,
#                         "lng": 150.8716658197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/camping-71.png",
#             "id": "98707f5061de759884c0ef508f06fc2bb49a869f",
#             "name": "Shellharbour Beachside Holiday Park",
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118103386380436701353\">Steve Mavin</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAvvD2xtcP1W-KSCl9b_znOo5SariHlrfhJoERAa5auQPpB1LfigcEfxD4vCP3wVPkB402tXkMYP5r1OGQKDmxzFKE4iac8Gd5Pd-ilYGiexL6RFirbCc5UUZADrNT8iV7EhAuw2hfvZhxbZV3ogWNVEAGGhR_nXiYBLTlM2mlpm_WeIewHIp_Ow",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJF2UVAYYUE2sRQmetWPF21-w",
#             "plus_code": {
#                 "compound_code": "CV9F+G6 Shellharbour, New South Wales, Australia",
#                 "global_code": "4RQGCV9F+G6"
#             },
#             "rating": 4.5,
#             "reference": "ChIJF2UVAYYUE2sRQmetWPF21-w",
#             "scope": "GOOGLE",
#             "types": [
#                 "campground",
#                 "lodging",
#                 "park",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 267,
#             "vicinity": "1 John Street, Shellharbour"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.565395,
#                     "lng": 150.8666922
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5641397197085,
#                         "lng": 150.8682511802915
#                     },
#                     "southwest": {
#                         "lat": -34.5668376802915,
#                         "lng": 150.8655532197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "faec9850513c9725bbb6ec9e5982792ace711d91",
#             "name": "Surfrider Caravan Park",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109497784148108962492\">Surfrider Caravan Park</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAeXH57rb5qKNSKjh1LhTTMsA6k4LEaeGqbRrpGiHtTf6hqNTtPncyN6YH6ATZKmXP51O3CTiheoJH6fIBO82XKVLqsESg2YiuXYJCJ2j3Ym8mLkV90qRxZcrjG2TA3igAEhC6EDxWlGXpE85Em3eWWNiEGhS53UXB4I3CPwBCZpjNUlNI3ELo5Q",
#                     "width": 1500
#                 }
#             ],
#             "place_id": "ChIJiePD83kUE2sROvhnz_pqziE",
#             "plus_code": {
#                 "compound_code": "CVM8+RM Barrack Point, New South Wales, Australia",
#                 "global_code": "4RQGCVM8+RM"
#             },
#             "rating": 3.8,
#             "reference": "ChIJiePD83kUE2sROvhnz_pqziE",
#             "scope": "GOOGLE",
#             "types": [
#                 "rv_park",
#                 "campground",
#                 "lodging",
#                 "park",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 109,
#             "vicinity": "50 Junction Road, Barrack Point"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.5639511,
#                     "lng": 150.8669417
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5626864697085,
#                         "lng": 150.8682228802915
#                     },
#                     "southwest": {
#                         "lat": -34.56538443029149,
#                         "lng": 150.8655249197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "069b31f3a5ae9164591a7a983c89f0005354ab3a",
#             "name": "Lazy Dayz Shellharbour",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116669642937758942425\">Lazy Dayz Shellharbour</a>"
#                     ],
#                     "photo_reference": "CmRaAAAABzFHnTq7DZW7re8F7vDk4diE7AcptsiStKaf6WopFWDXvKU09fMEJnEvubU2SiZ4CjNgW-h2Tk3LB1AfF462udQY7w7gKY4aCkKt8fIhMjgoXUn9-HHHpZUP4zd6JmKBEhBPgZEoqsuWvI53_n_H88tTGhTjtHwdnkz7xn0VA8aa4j1IuhToXg",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJYU0ItHAUE2sRAYHPlKgYX48",
#             "plus_code": {
#                 "compound_code": "CVP8+CQ Barrack Point, New South Wales, Australia",
#                 "global_code": "4RQGCVP8+CQ"
#             },
#             "rating": 4.3,
#             "reference": "ChIJYU0ItHAUE2sRAYHPlKgYX48",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 8,
#             "vicinity": "1 Iluka Road, Barrack Point"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.5627462,
#                     "lng": 150.8630484
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5613968697085,
#                         "lng": 150.8645002802915
#                     },
#                     "southwest": {
#                         "lat": -34.56409483029149,
#                         "lng": 150.8618023197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "2603bac2edabfac9e3f917852ccd52012dae431f",
#             "name": "Little Lake Apartment A & B",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 484,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115686995916066947291\">Little Lake Apartment A &amp; B</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAQrphVjizw3UzYUEwE867wFfTHVgqyXRftxhQJ5GazCMKCXdDVkDkPOBibTNI_S5OtdCSRStghHWu5GJnNl7wCNk0YASX8mLxHY7UEstGHcQ20TK1O_X5QcTlauveOxD_EhDJaPYWD6gqHnugGus4Hcr2GhRxdoFIXf5JKbgYN7lTSJfd32Y-0Q",
#                     "width": 728
#                 }
#             ],
#             "place_id": "ChIJ1xjqN9EVE2sRwyhfXXSdX4Q",
#             "plus_code": {
#                 "compound_code": "CVP7+W6 Barrack Heights, New South Wales, Australia",
#                 "global_code": "4RQGCVP7+W6"
#             },
#             "rating": 5,
#             "reference": "ChIJ1xjqN9EVE2sRwyhfXXSdX4Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "56 Jason Avenue, Barrack Heights"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -34.5634948,
#                     "lng": 150.8674105
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.5620669697085,
#                         "lng": 150.8688223302915
#                     },
#                     "southwest": {
#                         "lat": -34.5647649302915,
#                         "lng": 150.8661243697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "7938004b16927cd9426e776f23c12807f9de8a5a",
#             "name": "The Point",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113002468538292622857\">The Point</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAE5JlbXK0DJ95Nv1TGX99QqVtYX_7w0Q1HY2waMGJ9_fDB2s-azOwXVXIhyccDkvMxvZ7oxjVJ6d-u6tX8r4brhdUSX4Ogj9SpMXadftVeN-3LmQAwQFCf4Z-8_l2CuYYEhAb5H3Zjzkk-jmDfkjX4ruSGhS1E2hcILu2CsiyJJxZ0wTxsWY5SQ",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJSZgvtnAUE2sRyaJMdXDNgUg",
#             "plus_code": {
#                 "compound_code": "CVP8+JX Barrack Point, New South Wales, Australia",
#                 "global_code": "4RQGCVP8+JX"
#             },
#             "rating": 4.5,
#             "reference": "ChIJSZgvtnAUE2sRyaJMdXDNgUg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "2 Beach Road, Barrack Point"
#         }
#     ],
#     "status": "OK"
# }

# %%
target_coordinates = "22.57, 59.53" # coordinates of one of my cities
target_radius = 5000
target_type = "lodging"

# find the closest hotel of each type to coordinates

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": target_coordinates,
    "rankby": "distance",
    "type": target_type,
    "key": g_key,
}

response_2 = requests.get(base_url,params=params).json()
print(json.dumps(response_2, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCHgEAAPjJcjKCJoY1PUVRbILo0HyeWJ52i_dKChLsHmssQ6RE5fFRHLyrk_xDssYnw6cwI7HYAVHnjDuiIvMPwyVzqHmgmjP7xkNWXbEZy-EKi1fuqAHmQJjbs1aTi7x5oprwTYuu69Pam5dxrQZhIrgfu454QWNNhEfW4K0LFrvRluTKhpSoE8Jz8A3hWm6JTcgguoJfWhDIgJhGPTJ4fWQfOJuWMxnZXMxCDDDo_gwnTduQ0lByhfxvBEpx7x2pdeYj9LGiRLZg3SXWdhsIV40P-ZoDjQW-ehMCBi4-erXhWmwdyQzv_yc2kr0XwmvYlSr3WjvQZdw3oNcj6eKGGiykO5qJ0Jf5NgtZ6NOeYJ1bZMyFGtXL8wC_g-xX-0hDWOjjBBIQIYJTSSd3wsuh0rZSuMI2HhoU7RKrtQuHBqpGOZoD1yiSUjNA9JY",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.57,
#                     "lng": 59.53
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5710840302915,
#                         "lng": 59.53122863029149
#                     },
#                     "southwest": {
#                         "lat": 22.5683860697085,
#                         "lng": 59.52853066970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "26f49eb94de4fecc92be3db4f0a116057d364a7e",
#             "name": "Arabian Sea Motel",
#             "place_id": "ChIJJ9go_2-hkD4RcNIuPjCyb-A",
#             "plus_code": {
#                 "compound_code": "HG9J+X2 Sur, Oman",
#                 "global_code": "7HJXHG9J+X2"
#             },
#             "reference": "ChIJJ9go_2-hkD4RcNIuPjCyb-A",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Aseelah - Al Sharqiyah, Al Ashkharah, \u0635\u0648\u0631"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.5702211,
#                     "lng": 59.53052069999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5716550802915,
#                         "lng": 59.5319367802915
#                     },
#                     "southwest": {
#                         "lat": 22.5689571197085,
#                         "lng": 59.52923881970848
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "1881fec96e019685100d507eed5693ae022b993e",
#             "name": "Alafeeh Corniche Hotel Apartments",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116817399243897323988\">Martin G\u00f6sweiner</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAqCyrWvQGQRDkfkAPMenB1R6gr50Uy9dYP6_bzfL2LvP1vG_YrRtSdFeKCJAyXHuqaKnG9eImYo6Lkt4_eLpCL1P8N9QTaMyhz4q8VFdqNKP5QJJpHDvYgD7u6fsP8VyCEhD2FiY06c_hNtN4BBoYSqRHGhRAizBP0h9LS-IgqVUXg1tI29ur9g",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJMV2umG-hkD4RCCqrAWLYqRY",
#             "plus_code": {
#                 "compound_code": "HGCJ+36 Sur, Oman",
#                 "global_code": "7HJXHGCJ+36"
#             },
#             "rating": 3.7,
#             "reference": "ChIJMV2umG-hkD4RCCqrAWLYqRY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 101,
#             "vicinity": "Neema Corniche, Sur"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.56835,
#                     "lng": 59.526532
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5695851802915,
#                         "lng": 59.5278354302915
#                     },
#                     "southwest": {
#                         "lat": 22.56688721970849,
#                         "lng": 59.5251374697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "e2e6b98a134e316c3dfa39b8b6b80f8d04cba4e5",
#             "name": "Sur Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 900,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116664849943056230183\">Sur Hotel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAASqEb39oRAgdYGF59iMb44CBw6LQaSslmckgtHFBcnuqSEJkR830aM17JLNAwdJh3MIYZh3wXsXgBbZaMHxwsayX-wETtqFB9bbL6JxB4jEZUyVnQBvS-9ypBraffDL2eEhAf8CuGi76hMt3YWL_gXTSeGhSAX1zQcF-rv-aQUG84hVC_Ur45Cw",
#                     "width": 1200
#                 }
#             ],
#             "place_id": "ChIJS8HhXnChkD4RXLo8u5riWBI",
#             "plus_code": {
#                 "compound_code": "HG9G+8J Sur, Oman",
#                 "global_code": "7HJXHG9G+8J"
#             },
#             "rating": 3.6,
#             "reference": "ChIJS8HhXnChkD4RXLo8u5riWBI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 394,
#             "vicinity": "oman/sur/souq, Sur"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.5681822,
#                     "lng": 59.5264148
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5695113302915,
#                         "lng": 59.5277590802915
#                     },
#                     "southwest": {
#                         "lat": 22.5668133697085,
#                         "lng": 59.5250611197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "14cf808a6293d95e2c49de5c290a59c919cafc67",
#             "name": "Nasser sur hotel",
#             "photos": [
#                 {
#                     "height": 4000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100062300535502945120\">Alessandro Giannini</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAy7C6lMDcMCuICZHQ9oRsFKmWRod93YokwnJR_Bz66RbR2rMhmPSxS00W6F1MaCyHMVz46MgE87bf_5WZQ7MPRdDxCzth6pRcDCbaD-mk9hcCGExVYQa2k5ugBLDaPQ0LEhCZvgl4pfEzDqWIZeuFW7KHGhT_Y5039bJVhigy8Vm2CxJXanKlmg",
#                     "width": 2250
#                 }
#             ],
#             "place_id": "ChIJoZb1jHChkD4RFR0FSHIKzzA",
#             "plus_code": {
#                 "compound_code": "HG9G+7H Sur, Oman",
#                 "global_code": "7HJXHG9G+7H"
#             },
#             "rating": 4.3,
#             "reference": "ChIJoZb1jHChkD4RFR0FSHIKzzA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "oman sur, \u0635\u0648\u0631"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.5679624,
#                     "lng": 59.5264209
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5693847302915,
#                         "lng": 59.52779923029151
#                     },
#                     "southwest": {
#                         "lat": 22.5666867697085,
#                         "lng": 59.5251012697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "47c5738245fc87b765cf976a88ede10f5462acb6",
#             "name": "LPFP 2",
#             "place_id": "ChIJS4rxzn6hkD4R5pknxuR1YzE",
#             "plus_code": {
#                 "compound_code": "HG9G+5H Sur, Oman",
#                 "global_code": "7HJXHG9G+5H"
#             },
#             "reference": "ChIJS4rxzn6hkD4R5pknxuR1YzE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Sur"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.5702185,
#                     "lng": 59.5247687
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5715525802915,
#                         "lng": 59.5261093302915
#                     },
#                     "southwest": {
#                         "lat": 22.5688546197085,
#                         "lng": 59.52341136970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "2920ba704795908350293d4c1845e9251b99909f",
#             "name": "Future House LLC",
#             "place_id": "ChIJoXqTk_ihkD4RniwJK0Fmmf8",
#             "plus_code": {
#                 "compound_code": "HGCF+3W Sur, Oman",
#                 "global_code": "7HJXHGCF+3W"
#             },
#             "reference": "ChIJoXqTk_ihkD4RniwJK0Fmmf8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Sur"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.567643,
#                     "lng": 59.5253092
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5689601802915,
#                         "lng": 59.52675968029151
#                     },
#                     "southwest": {
#                         "lat": 22.5662622197085,
#                         "lng": 59.5240617197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "9dd37e2c80b60b8ba524351f56d9a037d16518a9",
#             "name": "Al Jumhour Hotel Apartments",
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114678360719532005599\">humaid alabri</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA-acP8Uh4Fv7y6htNF0vyXTEHR8kQTIfOtt_6hiClBwKLQmL5foka_W97xhXtP-7yc89j-YaYOW3IAl4HZhW-EMI7R2A2Df0NyHmCAcZg0z3jZPzoG4m9h9spNnbpnlS0EhBWv7olr5mezgXHoWmxlo0hGhQuHJ8dsptgWsu_LrJPTHuviJBrxg",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJezyI6nChkD4R-Pyjtwynh34",
#             "plus_code": {
#                 "compound_code": "HG9G+34 Sur, Oman",
#                 "global_code": "7HJXHG9G+34"
#             },
#             "rating": 3.3,
#             "reference": "ChIJezyI6nChkD4R-Pyjtwynh34",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 117,
#             "vicinity": "Oman"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.5708021,
#                     "lng": 59.5245246
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5722348802915,
#                         "lng": 59.52595478029151
#                     },
#                     "southwest": {
#                         "lat": 22.5695369197085,
#                         "lng": 59.52325681970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "e7d9516ea54b9af60b1f076f50d54aba040eaab1",
#             "name": "Salem Building",
#             "place_id": "ChIJ2_uK3NuhkD4RhUqr1CluYYQ",
#             "plus_code": {
#                 "compound_code": "HGCF+8R Sur, Oman",
#                 "global_code": "7HJXHGCF+8R"
#             },
#             "rating": 4,
#             "reference": "ChIJ2_uK3NuhkD4RhUqr1CluYYQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Near souq mosque, souq, \u0635\u0648\u0631"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.56556579999999,
#                     "lng": 59.5218128
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5668926802915,
#                         "lng": 59.52329243029149
#                     },
#                     "southwest": {
#                         "lat": 22.5641947197085,
#                         "lng": 59.52059446970848
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d7b6e2a34d32202d8c1ff59d9ecac8d8dbbdf250",
#             "name": "LULUAT AL AFIA HOTEL APARTMENTS(\u0644\u0624\u0644\u0624\u0629 \u0627\u0644\u0639\u0641\u064a\u0629 \u0644\u0644\u0634\u0642\u0642 \u0627\u0644\u0641\u0646\u062f\u0642\u064a\u0629)",
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107267234641885668007\">\u0645\u062d\u0645\u062f \u0645\u062d\u0645\u062f</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAWwEzVnd1iRP3Mdt_um7ShNi274FmGxL5JYlqO5D8jzT4fqk1LavvRs-4mkI66SfgZzaKXU_c7ZyLxMIsLax_oxxav6eZMnJ9dOQBO6uaUIPF-6zictedBP7-G7-YIEpSEhD83vTAo_QnnWyqndiSUn5HGhRijEZW7_5S9f-rmZ-UhEiFB4zC6w",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJEU4k43ahkD4RvmtiWrz0SmA",
#             "plus_code": {
#                 "compound_code": "HG8C+6P Sur, Oman",
#                 "global_code": "7HJXHG8C+6P"
#             },
#             "rating": 4,
#             "reference": "ChIJEU4k43ahkD4RvmtiWrz0SmA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 77,
#             "vicinity": "Unnamed road sur"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.5690426,
#                     "lng": 59.5404599
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5703508302915,
#                         "lng": 59.54178408029151
#                     },
#                     "southwest": {
#                         "lat": 22.5676528697085,
#                         "lng": 59.53908611970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "128af8b32ecfda9afa1f3df075c7d939b505b8a1",
#             "name": "\u0631\u0627\u0633 \u0627\u0644\u0645\u064a\u0644",
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116799778097284118767\">\u0627\u062d\u0645\u062f \u0627\u0644\u0639\u0644\u0648\u064a</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAD0oVUDBEUrCc88W1Q_ckRMlX9p_ESlKqeiVd-jqXtFBHgviWIFTHuMyrjQ-mdNG5x3N1K5N9TC8d2Ib1OvV6iHs-nz-GPLLyIlcbCzQ7vGxwiu1yKdRiNdgMwzq1PowSEhDXCS7aurvtGHiv8hm4yyD7GhQ2RvfUxG_YDXwiuw5MYGgxE8jn7A",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJFbrSmVWhkD4RQi6U6H-VlYw",
#             "plus_code": {
#                 "compound_code": "HG9R+J5 Sur, Oman",
#                 "global_code": "7HJXHG9R+J5"
#             },
#             "rating": 5,
#             "reference": "ChIJFbrSmVWhkD4RQi6U6H-VlYw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Sur"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.5759657,
#                     "lng": 59.52152959999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5772212802915,
#                         "lng": 59.5228091302915
#                     },
#                     "southwest": {
#                         "lat": 22.5745233197085,
#                         "lng": 59.52011116970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c0bd7a20ba3299fa828d1cca43a51e69c7573645",
#             "name": "Zaki Hotel Apartment",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 853,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117039251424035558412\">Zaki Hotel Apartment</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAVVhyxanZiInQcvNPNizjcdQgm11mD__yCLmwQtZD8Q7n-D80Fl2dQ173pjVFqIJwO2VLrwMb95_bT-ciky9aOwLffQQBb2huiadR5AwGcL93vgSgUu3CC96mCfIplCpQEhASJUlXzGuurrSrY9fdAFX0GhSSaJYrFJ1AsoyKJ89AzkxHruN0cg",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJ6Uir-n6hkD4R1BLARUMqj0A",
#             "plus_code": {
#                 "compound_code": "HGGC+9J Sur, Oman",
#                 "global_code": "7HJXHGGC+9J"
#             },
#             "rating": 4.3,
#             "reference": "ChIJ6Uir-n6hkD4R1BLARUMqj0A",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 207,
#             "vicinity": "Ash Sharqiyah Region Near Bawan Masjid Sur OM"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.5684371,
#                     "lng": 59.54329300000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5697907302915,
#                         "lng": 59.5446277802915
#                     },
#                     "southwest": {
#                         "lat": 22.56709276970849,
#                         "lng": 59.54192981970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c1c115d34c4770470d2136a7696df93703655813",
#             "name": "Tirky waleed",
#             "photos": [
#                 {
#                     "height": 3376,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106395903691746652457\">\u0627\u0628\u0648 \u0639\u0628\u062f\u0627\u0644\u0644\u0647 \u0627\u0644\u062d\u0634\u064a\u0645</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAuYmNqSa9yZ-ZJS8nLmWJ8Iqsxu7MqPcCQb78E_12qMln_3Ui7aHWyet5TE70Ji22tHVJ0rt7wczmU0gge04XOmUnJpZeu3PCVjNk4KDp7kpKoXWXDPLC1zCDQHHN2h27EhAc-1tLNOF12HTDQi4m68cNGhQHboiKhKLengrB_Fg870FBJVxNhw",
#                     "width": 5984
#                 }
#             ],
#             "place_id": "ChIJaxKxsSGhkD4Ri44fKzwAMeU",
#             "plus_code": {
#                 "compound_code": "HG9V+98 Sur, Oman",
#                 "global_code": "7HJXHG9V+98"
#             },
#             "reference": "ChIJaxKxsSGhkD4Ri44fKzwAMeU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u0635\u0648\u0631\u060c"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.5611036,
#                     "lng": 59.5412297
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5624345302915,
#                         "lng": 59.54266653029151
#                     },
#                     "southwest": {
#                         "lat": 22.5597365697085,
#                         "lng": 59.5399685697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "391d1afb40c465ed9d754887f9aadec41e518e75",
#             "name": "Al Ayjah Plaza Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3648,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102897295538699743968\">Y Ali</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAbjcQoZBPLZPHbicHW0nLScGvCpmufmgyNk6lfciIAcgGSsTisw3GZwVkerZ25DrDb8DxQ-8qlG6sBE_5nn94iVBK9YRlHrYYbGf74gffrTkbVGsZo98NC0TIoj_etvMzEhCTliqSj9TI3XttfIK4ROX9GhQUIMA7WN7FeUkpMH7Gvd6h9ydwqw",
#                     "width": 2736
#                 }
#             ],
#             "place_id": "ChIJvSDJeSqikD4RKjIsjBzZGAs",
#             "plus_code": {
#                 "compound_code": "HG6R+CF Sur, Oman",
#                 "global_code": "7HJXHG6R+CF"
#             },
#             "rating": 3.7,
#             "reference": "ChIJvSDJeSqikD4RKjIsjBzZGAs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 198,
#             "vicinity": "Al Ayjah, Sur, Sur"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.581197,
#                     "lng": 59.51865950000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5824822802915,
#                         "lng": 59.5199725302915
#                     },
#                     "southwest": {
#                         "lat": 22.5797843197085,
#                         "lng": 59.5172745697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "f52b9c11577724f622b3cbcd2a1dd9513758a867",
#             "name": "\u0627\u0644\u0631\u064a\u0627\u062f\u0629 \u0644\u0644\u0623\u062c\u0646\u062d\u0629 \u0627\u0644\u0641\u0646\u062f\u0642\u064a\u0629 Leading Wings Beach Hotel",
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103702662531133064501\">Vlastimil Luc\u00e1k</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA7rFKINKN_-Fe4lsHPpdEeCYNdVabuGiDiW9033JTNGPs5-bvie2153ISzKXmOmLgxXbp63DJ8B3Czk1hE1iovDT74LwSBTyb_762jQxC_2LGlS6rbtyHf2cZ720ZfMmfEhAZb9mE2KY7ae0ciPtL2qqbGhSnUdXjlwnA9uzbOhYllaXD5IX-zA",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJmRXYKdWjkD4Rncyr4vURAh4",
#             "plus_code": {
#                 "compound_code": "HGJ9+FF Sur, Oman",
#                 "global_code": "7HJXHGJ9+FF"
#             },
#             "rating": 3.2,
#             "reference": "ChIJmRXYKdWjkD4Rncyr4vURAh4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 93,
#             "vicinity": "Sur"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.5776325,
#                     "lng": 59.51503760000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5790763802915,
#                         "lng": 59.51645633029151
#                     },
#                     "southwest": {
#                         "lat": 22.57637841970849,
#                         "lng": 59.5137583697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "a2f212e0f2077daa818cc2e3eed947e339b14641",
#             "name": "OYO 111 Al Thabit Hotel",
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117664402039014761220\">Fahad 707</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA_JuGh1lCaH1if2M4g3wZ-MDDJN_Pd7wwSJy80hyFtIxKpDw4KTjVqwWdFGgkewf3URs6uADNdZGGg6wKgRz7NCUe2Zd7yAjXt_Nl71woTV5FnfecwGyC2FiUzrSdjJ-pEhBTeyZmwlAh_wbL4uPDsyvwGhQJcinl3rvX9WkIbxPSgy-jMQkEmQ",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJ6_ylbYChkD4RRC3pyplqlA0",
#             "plus_code": {
#                 "compound_code": "HGH8+32 Sur, Oman",
#                 "global_code": "7HJXHGH8+32"
#             },
#             "rating": 3.6,
#             "reference": "ChIJ6_ylbYChkD4RRC3pyplqlA0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 211,
#             "vicinity": "Sultanate Of Oman \u0635\u0648\u0631 OM"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.5817005,
#                     "lng": 59.5175255
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5829031802915,
#                         "lng": 59.5188688802915
#                     },
#                     "southwest": {
#                         "lat": 22.5802052197085,
#                         "lng": 59.51617091970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "4670c659eee5d17b882149b6a880f8756f04a772",
#             "name": "FIVE CONTINENTS HOTEL SUR SALTANATE OF OMAN",
#             "photos": [
#                 {
#                     "height": 2560,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104273223229099345009\">FIVE CONTINENTS HOTEL SUR SALTANATE OF OMAN</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAHn2lHohSU2kU80y1iYRXc6Y3j6mD8n9KeXGuVwS2jP-m0XpqEm8i7CheRhD5g8nL5ikOWUZGST3rh42V4OTWq61ypFjVg9yo4jga7geai2Jz7I7ywS6PSNKYnrSEp0KqEhC36ya5nhWDnNwZlLffLzK6GhSNS3IY-buAmQdElW4h5-On37Mt6Q",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJj14_kA6jkD4Rwdzofip7AEs",
#             "plus_code": {
#                 "compound_code": "HGJ9+M2 Sur, Oman",
#                 "global_code": "7HJXHGJ9+M2"
#             },
#             "rating": 2,
#             "reference": "ChIJj14_kA6jkD4Rwdzofip7AEs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "22.577888, 59.511566 Al SHARIYA H2A Road 23, Land Location 245 Sur OM"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.57740099999999,
#                     "lng": 59.5118129
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5787983302915,
#                         "lng": 59.51315923029151
#                     },
#                     "southwest": {
#                         "lat": 22.5761003697085,
#                         "lng": 59.51046126970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d55a5a6b9cbbaca83a9e81d673b0311e8915bad3",
#             "name": "Al Sqlawi Hotel Apartments",
#             "photos": [
#                 {
#                     "height": 460,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104783799380386789368\">\u0639\u0628\u062f\u0627\u0644\u0648\u0647\u0627\u0628 \u0627\u0644\u0645\u0639\u0645\u0631\u064a</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAShbX5EOE0qNFy4AzfxAeRz8yRh_FKcnl1qVoa9lAdMypmv2OlhJBjQncCCUsasGRMIAD1Wb6kmtAyjZtK3qcNRZvgTtemEahjZZ5joKkZ2MWwsIvbjJPVIhwAUzLxPlCEhDGnunk5LwSd1zuCU5C3oeUGhR3f7jP4DvHv9YWEv8KMenizS9Rog",
#                     "width": 693
#                 }
#             ],
#             "place_id": "ChIJY9GC_CmikD4RPGPaOKvZpCM",
#             "plus_code": {
#                 "compound_code": "HGG6+XP Sur, Oman",
#                 "global_code": "7HJXHGG6+XP"
#             },
#             "rating": 3.4,
#             "reference": "ChIJY9GC_CmikD4RPGPaOKvZpCM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 127,
#             "vicinity": "Oman"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.5778125,
#                     "lng": 59.5115625
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5791295802915,
#                         "lng": 59.51291468029149
#                     },
#                     "southwest": {
#                         "lat": 22.5764316197085,
#                         "lng": 59.51021671970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "cd20950fb39d29fe13248dcbaf54336a950f5d98",
#             "name": "FIVE CONTINENTS HOTEL SUR SALTANATE OF OMAN",
#             "photos": [
#                 {
#                     "height": 2560,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117219966002400995683\">fivecontinent hotel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA96SOE_3RxFB4LzFESrFo0YSFuxMvmPYG4FR0SZqQtgvp8BNONztoWbK-ogjV_H-29OKGiXy98UvKuwjtrs8gDlcEj081IeesG8waJ5Xeu5KKIzl9t_22q1z7VbBVkjnaEhAUruRFjrLgPvX7TIMX1IokGhT31GLPqDQf9oPIQxYsO_1x4wxbaA",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJI9lxeu6jkD4RWymHImuy3HE",
#             "plus_code": {
#                 "compound_code": "HGH6+4J Sur, Oman",
#                 "global_code": "7HJXHGH6+4J"
#             },
#             "reference": "ChIJI9lxeu6jkD4RWymHImuy3HE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "HGH6+4J Sur Sur OM"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.5778655,
#                     "lng": 59.5115723
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5791930302915,
#                         "lng": 59.51292343029151
#                     },
#                     "southwest": {
#                         "lat": 22.57649506970849,
#                         "lng": 59.5102254697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "f0f26a199e151a1155c1a54ec5b4e4b5642da89b",
#             "name": "FIVE CONTINENTS HOTEL",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJDypEw1ijkD4Rhp4t1YjR-tY",
#             "plus_code": {
#                 "compound_code": "HGH6+4J Sur, Oman",
#                 "global_code": "7HJXHGH6+4J"
#             },
#             "reference": "ChIJDypEw1ijkD4Rhp4t1YjR-tY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Al-Shariya Public Park, 22.577888, 59.511567 Sur City, Road 23, Location 245, H2A"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.5795619,
#                     "lng": 59.51201369999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.5809862302915,
#                         "lng": 59.51341388029151
#                     },
#                     "southwest": {
#                         "lat": 22.5782882697085,
#                         "lng": 59.5107159197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "a74f016f2aaffe84ca2536339104e3101a98d56f",
#             "name": "Al Diwaniya omani sweets sur",
#             "place_id": "ChIJ3VRnxzmjkD4RDXY3BUW_8r8",
#             "plus_code": {
#                 "compound_code": "HGH6+RR Sur, Oman",
#                 "global_code": "7HJXHGH6+RR"
#             },
#             "reference": "ChIJ3VRnxzmjkD4RDXY3BUW_8r8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Sur"
#         }
#     ],
#     "status": "OK"
# }

# %%
target_coordinates = "20.66, -74.94" # coordinates of one of my cities
target_radius = 5000
target_type = "lodging"

# find the closest hotel of each type to coordinates

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": target_coordinates,
    "rankby": "distance",
    "type": target_type,
    "key": g_key,
}

response_3 = requests.get(base_url,params=params).json()
print(json.dumps(response_3, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.6570186,
#                     "lng": -74.9452366
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.6583265302915,
#                         "lng": -74.94388006970848
#                     },
#                     "southwest": {
#                         "lat": 20.6556285697085,
#                         "lng": -74.9465780302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "bdd1c119a810e61f3fb764a9a3d8eeff3522e3e2",
#             "name": "Renta en Divisa",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108899162789335647242\">Jorge Luis Velazquez Gonzalez</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAPwSoBWpZvNRXQ8_Wt27SOQmlYgadBgNttQgw9UVDcWpLDUxlHmZ99b2ssILvmjatnNRR38Ov_jTkW_gbz6yy9zfo7pyzgjB5AUXdPVgGqc9fch7zq1Sbsu4hzQ5CCyLMEhB8FX9tfc2DdKABKGTHlc0DGhRm_01hJoQ-wfp97rKf24bQ5O8yrg",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJ8RBYDKT3y44RiflSjlBLE9M",
#             "plus_code": {
#                 "compound_code": "M343+RW Moa, Cuba",
#                 "global_code": "77G7M343+RW"
#             },
#             "rating": 5,
#             "reference": "ChIJ8RBYDKT3y44RiflSjlBLE9M",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Unnamed Road, Moa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.6595759,
#                     "lng": -74.9502066
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.6611177302915,
#                         "lng": -74.94880071970849
#                     },
#                     "southwest": {
#                         "lat": 20.65841976970849,
#                         "lng": -74.95149868029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "bcbc18185f1a24d859c2b9a03584db38b400132b",
#             "name": "ARRENDADOR EN DIVISA",
#             "place_id": "ChIJmyGT-3H3y44RtFhAcfJ7bck",
#             "plus_code": {
#                 "compound_code": "M25X+RW Moa, Cuba",
#                 "global_code": "77G7M25X+RW"
#             },
#             "rating": 5,
#             "reference": "ChIJmyGT-3H3y44RtFhAcfJ7bck",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Moa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.6574573,
#                     "lng": -74.9501034
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.6588156302915,
#                         "lng": -74.9487077697085
#                     },
#                     "southwest": {
#                         "lat": 20.6561176697085,
#                         "lng": -74.95140573029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "6a9cc8d77a9b9ae7c6dd783a06a6b5d5d4521535",
#             "name": "RENTA EN DIVISA",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJZ_pg5Df3y44Rfi5VdjKDCCU",
#             "plus_code": {
#                 "compound_code": "M24X+XX Moa, Cuba",
#                 "global_code": "77G7M24X+XX"
#             },
#             "reference": "ChIJZ_pg5Df3y44Rfi5VdjKDCCU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Reparto: Caribe, Ave. Carlos J. Finlay #8 Altos E/Sim\u00f3n Bolivar y Calle Addiel Navarro, Moa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.6649743,
#                     "lng": -74.95191419999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.6662489802915,
#                         "lng": -74.9506438697085
#                     },
#                     "southwest": {
#                         "lat": 20.6635510197085,
#                         "lng": -74.9533418302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d64f22903d7916f74e001aac0b64b1f1b4f87286",
#             "name": "Islazul Miraflores",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2576,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101600143533853199809\">Jose Antonio Cabrera</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAKuqDtjpOoR207UzrlFdzoGaeLiouZMs4VJZCc6m0zPMVJiW_qqMFRoh1j7Ej9S2C3jX7hoopYENBj9TzHYMxCSOQuatsIP4Afw_6GoGjZlG1Zgw5dT_xCryBrcaICwJKEhANP7nrH-7LfA_EkkHo40r1GhQcpKZMHbYiYcsit_AU7KFXdREmhw",
#                     "width": 1932
#                 }
#             ],
#             "place_id": "ChIJ3_Y2HAT3y44R6aCnhBTZgc0",
#             "plus_code": {
#                 "compound_code": "M27X+X6 Moa, Cuba",
#                 "global_code": "77G7M27X+X6"
#             },
#             "rating": 4.7,
#             "reference": "ChIJ3_Y2HAT3y44R6aCnhBTZgc0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Cuba"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.6649712,
#                     "lng": -74.9519169
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.6662473302915,
#                         "lng": -74.9506450697085
#                     },
#                     "southwest": {
#                         "lat": 20.6635493697085,
#                         "lng": -74.9533430302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "7662156ebbeb007f45e73892a9f2f0e638db91f2",
#             "name": "Miraflores",
#             "photos": [
#                 {
#                     "height": 902,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118398171429732989265\">A Hasenbank</a>"
#                     ],
#                     "photo_reference": "CmRaAAAADr6eYAf_Yb0EfqTtXVOf0Ngu4ELOrdDZkg-urwT0ZO9fZ23HVNnYdtz8XOsB7BPG-PJGrgYXyJN4X4e8ynJ8E4PkTSyISU2mdgFVbBAHbYgw12aej1f8sWeoFi5toKqVEhBfPvtAO_M14mR-36WIuYQ5GhRlI0ovPezqVH1ul3wTvonzKudrLg",
#                     "width": 1600
#                 }
#             ],
#             "place_id": "ChIJgSneFTP2y44R64rNJV2bHio",
#             "plus_code": {
#                 "compound_code": "M27X+X6 Moa, Cuba",
#                 "global_code": "77G7M27X+X6"
#             },
#             "rating": 3.8,
#             "reference": "ChIJgSneFTP2y44R64rNJV2bHio",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 11,
#             "vicinity": "123, Moa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.662369,
#                     "lng": -74.953306
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.6637168302915,
#                         "lng": -74.9519438197085
#                     },
#                     "southwest": {
#                         "lat": 20.6610188697085,
#                         "lng": -74.95464178029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "48ddfa31ec314437a50425efe8a9e053d2f49e17",
#             "name": "Residencia de Posgrado ISMMM",
#             "place_id": "ChIJ0cqv7ED3y44R53uIMxrrj8E",
#             "plus_code": {
#                 "compound_code": "M26W+WM Moa, Cuba",
#                 "global_code": "77G7M26W+WM"
#             },
#             "reference": "ChIJ0cqv7ED3y44R53uIMxrrj8E",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Universidad de"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.649364,
#                     "lng": -74.9271385
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.6507353302915,
#                         "lng": -74.9258132697085
#                     },
#                     "southwest": {
#                         "lat": 20.6480373697085,
#                         "lng": -74.9285112302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "353ff0e13379a34b9e56de8abfe7c4d17441c0ea",
#             "name": "Actualmente donde Vivo",
#             "place_id": "ChIJ3YY73n_3y44RikkiLM_ZPmQ",
#             "plus_code": {
#                 "compound_code": "J3XF+P4 Moa, Cuba",
#                 "global_code": "77G7J3XF+P4"
#             },
#             "reference": "ChIJ3YY73n_3y44RikkiLM_ZPmQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Moa"
#         }
#     ],
#     "status": "OK"
# }

# %%
target_coordinates = "-31.54, -68.54" # coordinates of one of my cities
target_radius = 5000
target_type = "lodging"

# find the closest hotel of each type to coordinates

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": target_coordinates,
    "rankby": "distance",
    "type": target_type,
    "key": g_key,
}

response_4 = requests.get(base_url,params=params).json()
print(json.dumps(response_4, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCHgEAAFAN6HFSGgWrlgxhoydHSPRmvg5L_RnJHcLUdK-2R0ucI0oumxLK0IctOs8hyaCKUMxggD0Ojs7tvLbK7T3fGjZIX-6KfYm7oBD003l2hU6K_paAvxjEo1eo2G0IdyGRpT3FYlUD4VGpDa5DMOibU5Njwgkji5wvpVRz29dUAZSOs_B0Lcl8ATCtd-FNOqkdBv3LcTP7_cvCF8KhEz02y0NluMtcoRI26AmmP0GL2OZibIaOTQ6U1jMw3m18be4a1K2DASZsHJT4BPYRw2gNIoCwu4LNZwjztD-3LOTfaGURI7kF58gtqB5piObHpCLDMvN9589nW7JmBE8BXZu_zmWz1vczF3UiQT9a9CZqxGx3XsN9GZv3ho0NNt7YmOj2fhIQFRccq-N6x3dY7PSpdw_5lRoUnm43VZm9wuDEbFp3IFbTnUxwDHQ",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.5414127,
#                     "lng": -68.5394014
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5400518697085,
#                         "lng": -68.5379376197085
#                     },
#                     "southwest": {
#                         "lat": -31.5427498302915,
#                         "lng": -68.54063558029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d0ff1f91aef88b9ccc7940b532120ff132efd78b",
#             "name": "Departamento Hospedaje",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4128,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104257336053996846632\">Pedro Montenegro</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAzpv7aiAo51k_F3CpTvVKTrZcyi4dCYbcibKxT1KS_r_kr_0T-kl_5TzO7U1qnDSs_cosAu-sRiMPaTXReZDD8zCFypy40EU6H-wu3MN2xL-evO6YRqra6F_omE-Mqy0NEhCn_Lf-YXVIR14o8dCzcFdUGhQiKpjY_1q34faHwh2hIFuVaBpRpQ",
#                     "width": 3096
#                 }
#             ],
#             "place_id": "ChIJK7neJzFBgZYRJK6D9TR7oE8",
#             "plus_code": {
#                 "compound_code": "FF56+C6 San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF56+C6"
#             },
#             "reference": "ChIJK7neJzFBgZYRJK6D9TR7oE8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Suipacha 527, J5402FQE"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.5387271,
#                     "lng": -68.5428475
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5373664197085,
#                         "lng": -68.5414422197085
#                     },
#                     "southwest": {
#                         "lat": -31.5400643802915,
#                         "lng": -68.5441401802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "b3fda431887b801e23b32a8879e600a6e4676af1",
#             "name": "Apart Hotel Provincia del Huarpe",
#             "photos": [
#                 {
#                     "height": 3096,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115896178477495909144\">natalia sala</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA9eUuTb5bEhHRO5U_Ne49A2xcoLalZ-y8NZzRdXi_RbVPSdh_BUyT4A9lWXny2Gh25bxup2YQlB6OZEnutGOeGMhtYN9bpeYjmjdZBpZEk9dbDy4yZ3armrYMVVaKfpydEhD3EncTExvGMAA6ygAulenJGhTch2C4oveCiUWdTJZwRrnA3biLhw",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJLZmkLTdAgZYRwj-DvdEtexQ",
#             "plus_code": {
#                 "compound_code": "FF64+GV San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF64+GV"
#             },
#             "rating": 4.2,
#             "reference": "ChIJLZmkLTdAgZYRwj-DvdEtexQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 41,
#             "vicinity": "Juez Ram\u00f3n D\u00edaz Sur, San Juan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.5420896,
#                     "lng": -68.5377379
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5407405197085,
#                         "lng": -68.5363881697085
#                     },
#                     "southwest": {
#                         "lat": -31.5434384802915,
#                         "lng": -68.53908613029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "6c9648484d021dca292602a220113c6d2e29bf9a",
#             "name": "Hotel Ischigualasto",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2184,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110487585008035137955\">Hotel Ischigualasto</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAYpf9RhfrRIWGpt1E3atZP6h5oltRjcpUw0RvOM9njJTPSNsVKYBBgGICS6zmQBo-QIs-aXSVOG7Pl5eYb141ADbywiZE1P3dFnkK0lXg0z0qhGotWdC6HgBedd2jzBpoEhD1QSQgI_Msbh4CwvoHi1b9GhTG2sgfTplmOMzwva3C8UR_6jsCqQ",
#                     "width": 2912
#                 }
#             ],
#             "place_id": "ChIJ71EiwzpAgZYRdF-FPwJ5gkg",
#             "plus_code": {
#                 "compound_code": "FF56+5W San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF56+5W"
#             },
#             "rating": 3.8,
#             "reference": "ChIJ71EiwzpAgZYRdF-FPwJ5gkg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 268,
#             "vicinity": "Las Heras Sur 575, San Juan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.5380434,
#                     "lng": -68.54263399999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5367184697085,
#                         "lng": -68.54141841970848
#                     },
#                     "southwest": {
#                         "lat": -31.5394164302915,
#                         "lng": -68.5441163802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "5374a0ef0f1bbd678c989044edae15b3294a09d9",
#             "name": "Edificio Calabria",
#             "place_id": "ChIJe-1H_FRBgZYRj-OJrQZCgTs",
#             "plus_code": {
#                 "compound_code": "FF64+QW San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF64+QW"
#             },
#             "reference": "ChIJe-1H_FRBgZYRj-OJrQZCgTs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Juez Ram\u00f3n D\u00edaz 330-340, San Juan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.53712609999999,
#                     "lng": -68.5384229
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5357705697085,
#                         "lng": -68.5369900197085
#                     },
#                     "southwest": {
#                         "lat": -31.5384685302915,
#                         "lng": -68.5396879802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "b9b85d8fa1dfb25f7c4c9bd791cc133acdd0f127",
#             "name": "Civico Art Hotel",
#             "photos": [
#                 {
#                     "height": 2336,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100543077376301312691\">Carmen Real</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA-KgLl6MgdyPTKQ1FZjjJBQnTLx-n7wsXaTotgb_4AEkVHLOHiY_hK1pEIphz8aTxdfoomgU3zzVNVKPWb-sUQMe6pO5bw0DIXYwaK1lGnDV-guR2cQl0SijHM-MxjiySEhA9rRmRBSvUpdO1uDrzRhTXGhRLDrffvvAaMU7uUbaT6ro8Oodg7w",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJvyu_tzFAgZYRfb-FhFA31kA",
#             "plus_code": {
#                 "compound_code": "FF76+4J San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF76+4J"
#             },
#             "rating": 4.3,
#             "reference": "ChIJvyu_tzFAgZYRfb-FhFA31kA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 443,
#             "vicinity": "Las Heras Sur 209, San Juan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.5400316,
#                     "lng": -68.5360752
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5386810697085,
#                         "lng": -68.5347081697085
#                     },
#                     "southwest": {
#                         "lat": -31.5413790302915,
#                         "lng": -68.5374061302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "9d62bf51d3620c1dbb6538f83b74435f0f759929",
#             "name": "estadia san juan",
#             "place_id": "ChIJEV-tVyVAgZYR2cSokp4YZlU",
#             "plus_code": {
#                 "compound_code": "FF57+XH San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF57+XH"
#             },
#             "reference": "ChIJEV-tVyVAgZYR2cSokp4YZlU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Avenida Espa\u00f1a Sur 422, J5402DRR"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.5390836,
#                     "lng": -68.53617249999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5377337697085,
#                         "lng": -68.5348124197085
#                     },
#                     "southwest": {
#                         "lat": -31.54043173029149,
#                         "lng": -68.53751038029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c2ec4db1f8175606f892cd3941e966c53028a14f",
#             "name": "Hotel Angelus",
#             "photos": [
#                 {
#                     "height": 3264,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102884673676516770455\">Alicia Soria</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAZJGrnlxlMzNQGpov2AH2gV50Td-yqxmFD8yPLi6WBCNRkVgj9tjcu2XLb4ke8uKUM7oDwDEp_JEiBFciMQ8YpUr2jHlTSOCSeSgkdLJubfROAfDFZGepK3AfgKnBpqzTEhBQP9klxrCQ-dluOQCjLwZNGhTzAUr-acFnrrhE-WR15moT1hjDoA",
#                     "width": 2448
#                 }
#             ],
#             "place_id": "ChIJX9L05C9AgZYR2J3iK3TDxeI",
#             "plus_code": {
#                 "compound_code": "FF67+9G San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF67+9G"
#             },
#             "rating": 2.9,
#             "reference": "ChIJX9L05C9AgZYR2J3iK3TDxeI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 8,
#             "vicinity": "Avenida Espa\u00f1a Sur 302-400"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.53907950000001,
#                     "lng": -68.5361258
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.53773331970851,
#                         "lng": -68.5348125197085
#                     },
#                     "southwest": {
#                         "lat": -31.5404312802915,
#                         "lng": -68.5375104802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "21171aeb3cd33ac2394b4af26394a870291401f1",
#             "name": "hotel del gringo",
#             "place_id": "ChIJ1ar65C9AgZYRl2JmYwnd1Pg",
#             "plus_code": {
#                 "compound_code": "FF67+9G San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF67+9G"
#             },
#             "reference": "ChIJ1ar65C9AgZYRl2JmYwnd1Pg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "J5402DRQ, Avenida Espa\u00f1a Sur 302-400, San Juan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.5390622,
#                     "lng": -68.5360857
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5377176697085,
#                         "lng": -68.53479376970849
#                     },
#                     "southwest": {
#                         "lat": -31.5404156302915,
#                         "lng": -68.5374917302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "0b2756799bf33d0865fc9703ffd9273c9e154d95",
#             "name": "Hotel el Mendocino",
#             "photos": [
#                 {
#                     "height": 1836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112597017233628692777\">Odin Artesanal</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAO94qUzcwS2YW58OxCnF6bTSJ9MYUJEXmTAFsj_AKprmQA-8AiW8kbgWDTFL9r9N-cqvoKu-Itovrr2-9pGSdOeWXzLM9pjmofU9lS72NWwucomWCKYIJVoXavTo_t_l3EhDWGXabSQ6ALn9vud5QtZqtGhRkCxr-vT2xPS2OGVX0LXAwNGZlcA",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJmfGk4y9AgZYRcNEJSMJQcD8",
#             "plus_code": {
#                 "compound_code": "FF67+9H San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF67+9H"
#             },
#             "rating": 3.4,
#             "reference": "ChIJmfGk4y9AgZYRcNEJSMJQcD8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 83,
#             "vicinity": "Avenida Espa\u00f1a Sur 344, DRQ"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.5400189,
#                     "lng": -68.5359015
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5386781697085,
#                         "lng": -68.53464856970851
#                     },
#                     "southwest": {
#                         "lat": -31.5413761302915,
#                         "lng": -68.53734653029152
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "041fca532368a78e0af339688ad9ddc0ee0bcea6",
#             "name": "Hotel Estrella Andina",
#             "photos": [
#                 {
#                     "height": 1836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105914709716368150634\">Estela Marta Roca</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAixq0DfGwDyfLx0WQB708FoJZNfLFVGVtbDYQC3pam7FMvnRqPeTu9j0a6qHyZvwdJqz6AEk0KJ6t0UtEgUc9-5yDahTXh4MEQ8pDSZo8GiDzLxLYqISeine0xky9ZYp7EhBWju-T31DqBG5COo_iYGLLGhQNz8SmSlNOHzZTNRy70N5_akTkUw",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJV2ocVyVAgZYRQNJsQceoV0c",
#             "plus_code": {
#                 "compound_code": "FF57+XJ San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF57+XJ"
#             },
#             "rating": 3.6,
#             "reference": "ChIJV2ocVyVAgZYRQNJsQceoV0c",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 350,
#             "vicinity": "sur, J5402DRR, Avenida Espa\u00f1a Sur 422, DRR"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.538969,
#                     "lng": -68.5360437
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5376265197085,
#                         "lng": -68.53477756970848
#                     },
#                     "southwest": {
#                         "lat": -31.5403244802915,
#                         "lng": -68.53747553029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "b4dfd88505580ed1ac108acd27e54ace5a0fbae7",
#             "name": "Cactus Hostel",
#             "place_id": "ChIJ17W35S9AgZYRPq2e0I0AamE",
#             "plus_code": {
#                 "compound_code": "FF67+CH San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF67+CH"
#             },
#             "reference": "ChIJ17W35S9AgZYRPq2e0I0AamE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Avenida Espa\u00f1a Sur 332, DRQ"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.538969,
#                     "lng": -68.5360437
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5376265197085,
#                         "lng": -68.53477756970848
#                     },
#                     "southwest": {
#                         "lat": -31.5403244802915,
#                         "lng": -68.53747553029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "10915d372250318c70c200edc7de9cf5bfb36ec2",
#             "name": "El Hostel Del Chango",
#             "place_id": "ChIJ17W35S9AgZYRaBDWsc1R2e8",
#             "plus_code": {
#                 "compound_code": "FF67+CH San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF67+CH"
#             },
#             "reference": "ChIJ17W35S9AgZYRaBDWsc1R2e8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Avenida Espa\u00f1a Sur 332, DRQ"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.53897220000001,
#                     "lng": -68.53604179999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.53762976970851,
#                         "lng": -68.53477641970848
#                     },
#                     "southwest": {
#                         "lat": -31.54032773029151,
#                         "lng": -68.53747438029148
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "042205384e54cabfd555af959c6f85ab9e032de2",
#             "name": "Hotel Brescia",
#             "photos": [
#                 {
#                     "height": 3096,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101752554219124196353\">Pedro Silvestre</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAzxMBVv4ZyEry6ly_pK6gf1FvuDDc8ufy7ZUYEpt0y2T7TrN9aQ8PzORE87L7eQTAsZIR0Bq4m-gRp5sIUfkphzLldDRyEw7_KEMp5Jdcu7Nje9vJUBdp2fsdL727ATowEhDsldkz0oQCLN4v2UB-reNXGhRz5r0-DlvkXsdS5Rc-_i9ALydymA",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJGTvF4y9AgZYRdURRas_6RME",
#             "plus_code": {
#                 "compound_code": "FF67+CH San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF67+CH"
#             },
#             "rating": 3.6,
#             "reference": "ChIJGTvF4y9AgZYRdURRas_6RME",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 122,
#             "vicinity": "Avenida Espa\u00f1a Sur 336, DRQ"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.5388808,
#                     "lng": -68.53606529999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5375378197085,
#                         "lng": -68.53479316970851
#                     },
#                     "southwest": {
#                         "lat": -31.5402357802915,
#                         "lng": -68.53749113029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "24a5d8852d9f941b990d48d77dffdc465f19b683",
#             "name": "Hotel Cuesta del Viento",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2340,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116989178401085995060\">Alfredo Asurmendi</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA0td9WB4edUA3b2qKcCl3arwFwO4P5f7BRsFh4b9GcZ4Y4NnnjbNu1ftXWhV4TNp_8dmlzlCsTUOuS1lZQHxaV4AOnNzzDUc6Zks2y-nO8sx_682wT3J21z3bctf1gu4kEhA976XaHAnI-dfUDp7nYL3LGhR22JTP7En3cbdG1r3zTsX71sPTVg",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJcxYF4S9AgZYRO6YTEPs7pXc",
#             "plus_code": {
#                 "compound_code": "FF67+CH San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF67+CH"
#             },
#             "rating": 3.7,
#             "reference": "ChIJcxYF4S9AgZYRO6YTEPs7pXc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 255,
#             "vicinity": "Avenida Espa\u00f1a Sur 320, DRQ"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.5383413,
#                     "lng": -68.53613469999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5370062197085,
#                         "lng": -68.53487026970849
#                     },
#                     "southwest": {
#                         "lat": -31.53970418029149,
#                         "lng": -68.5375682302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "68f8d9baaa42b612cf33cec1a1619a80c308ec8c",
#             "name": "Hotel San Francisco",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118405288133158612836\">Pablo De Luca</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAk_kHPrCviZ48cMu5oh8fnP7i5AEfSjNcueatvVb27nDse13dx7ugPyduUCDCKA_r67dRYSS4srXpfrPzz8oXUK08AgvsPe1cr_2SRoEO0bai3hx6RZ8Cx61hkB1qfIS2EhCoAQ2DK8_4OE_qQr20s4uZGhTh-h4Ah0jpE8zzpii0GyZJdPP2Ag",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJvYkd3y9AgZYRU02gnU94r3k",
#             "plus_code": {
#                 "compound_code": "FF67+MG San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF67+MG"
#             },
#             "rating": 3.9,
#             "reference": "ChIJvYkd3y9AgZYRU02gnU94r3k",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 121,
#             "vicinity": "Avenida Espa\u00f1a Sur 284, San Juan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.5365762,
#                     "lng": -68.5417774
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5352313697085,
#                         "lng": -68.5403790697085
#                     },
#                     "southwest": {
#                         "lat": -31.5379293302915,
#                         "lng": -68.5430770302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "a2f117752e840fadbb2dbb582279d0cbe927aad7",
#             "name": "Complejo Nazareno",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2592,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102408678875437510532\">Carlos Fernandez</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAfa3ntwqhQpJmZcvHV8slK6aLZzLJkq75vWVK1SEnQ4YPuSkYduJqQweRgY0i1HAV-UbFj5HVtDYDOFNUxdCyghfsnnDGqfjCD4qq8bN9QT946tNBRlHT0KzzUos8VsmPEhASyUXkSFJ2bg-F_pqjjndIGhQkBqFqqaJjpfRJw1xkyqwoVOMVcw",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJu1o-RjFAgZYRG2AFIq_2600",
#             "plus_code": {
#                 "compound_code": "FF75+97 San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF75+97"
#             },
#             "rating": 4.2,
#             "reference": "ChIJu1o-RjFAgZYRG2AFIq_2600",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 77,
#             "vicinity": "Segundino Navarro 205, San Juan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.5379455,
#                     "lng": -68.536075
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5366383697085,
#                         "lng": -68.5347231697085
#                     },
#                     "southwest": {
#                         "lat": -31.5393363302915,
#                         "lng": -68.5374211302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "6f98eba024636640ef2541dbbb5ab79d7f8ba618",
#             "name": "El Andino",
#             "photos": [
#                 {
#                     "height": 3984,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106903297032441197998\">Alejandro Goldin</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAGGtTC7mRgUBY3twJnV6nFvb-Wh_0BUBcSEZZ1RSXdnNxRJ9EArwO-P26n6PM-tN08aWXb44FnGTQjonqQF4ypkpseGI9vY1R91nZaAZFTgqp8C0gUO9wvgfBll6eBv-4EhBM4TONW7ipgLjKIpNKApHHGhRjirrlLCCwbqibjHC-EK2YnI9D0g",
#                     "width": 2988
#                 }
#             ],
#             "place_id": "ChIJTbiK2i9AgZYRvauqphM8aY8",
#             "plus_code": {
#                 "compound_code": "FF67+RH San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF67+RH"
#             },
#             "rating": 4.2,
#             "reference": "ChIJTbiK2i9AgZYRvauqphM8aY8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "693, J5402DCG, Avenida Jos\u00e9 Ignacio de la Roza Oeste 601, San Juan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.5377269,
#                     "lng": -68.53616319999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.53638651970849,
#                         "lng": -68.5349357697085
#                     },
#                     "southwest": {
#                         "lat": -31.53908448029149,
#                         "lng": -68.5376337302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "f7648768cef1313bf538b88c766836ea9ce8ce75",
#             "name": "Hospedaje El Mendocino",
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105845357432697147934\">Aguas con la Bici</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAW7OPgSeJyvs96reld6J2fk2T2dQWhl7yXVItGGt5-xMqju0pU5AuThoraTAvT21Y3_7eHO8g8EU4iqhwiyZ0OYdz_e7wmrF1LmANVYl-UK36FPMxM5AS-Bzddaap_h4BEhBxm4vR2r3pJftRXwf4ujK3GhRbu3gZEltXUBFvVBLSgeLiYX6xQg",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJcXJJ1i9AgZYRhWPAwS86Qcc",
#             "plus_code": {
#                 "compound_code": "FF67+WG San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF67+WG"
#             },
#             "rating": 3.4,
#             "reference": "ChIJcXJJ1i9AgZYRhWPAwS86Qcc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "San Juan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.5376023,
#                     "lng": -68.5362614
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5362588697085,
#                         "lng": -68.5349912197085
#                     },
#                     "southwest": {
#                         "lat": -31.5389568302915,
#                         "lng": -68.53768918029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "76cac395f8623c7831afd723ac5d9a5d3fc297ae",
#             "name": "Gonzalez Roberto F",
#             "place_id": "ChIJD_2kKi5AgZYRakUydv8XrE4",
#             "plus_code": {
#                 "compound_code": "FF67+XF San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF67+XF"
#             },
#             "rating": 2.7,
#             "reference": "ChIJD_2kKi5AgZYRakUydv8XrE4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Avenida Espa\u00f1a Sur 192, DRO"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -31.535941,
#                     "lng": -68.5393318
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.5345739197085,
#                         "lng": -68.5379750697085
#                     },
#                     "southwest": {
#                         "lat": -31.5372718802915,
#                         "lng": -68.5406730302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "ea2630f32e9ac9ea0f9828769cebfdcefdb721b0",
#             "name": "HOSTEL CARRASCAL",
#             "photos": [
#                 {
#                     "height": 302,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111679916931533477083\">EDGAR NU\u00d1EZ</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA9dg5tpBIfURbX7UymVkxfUy5TZI0n90FFAr4FYYGJSnJQ38FDVMBaTkBe20auJvCHuG2uahuaJghz2Kf1gANlplMKbGqHAGeFSFzfbkT1GLHFxp6hR1d5ci3C9XWLZCNEhDQ8mwNuD1_yXZOprljedImGhQj2riZjmgjfy5Qdss_wmGuDiFsFQ",
#                     "width": 400
#                 }
#             ],
#             "place_id": "ChIJ06RpnDFAgZYRwQtWidMRma8",
#             "plus_code": {
#                 "compound_code": "FF76+J7 San Juan, San Juan Province, Argentina",
#                 "global_code": "47WHFF76+J7"
#             },
#             "rating": 4,
#             "reference": "ChIJ06RpnDFAgZYRwQtWidMRma8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "187, Francisco N. Laprida Oeste, San Juan"
#         }
#     ],
#     "status": "OK"
# }

# %%
hotel_names = []

hotel_names.append(response["results"][0]["name"])
hotel_names.append(response_2["results"][0]["name"])
hotel_names.append(response_3["results"][0]["name"])
hotel_names.append(response_4["results"][0]["name"])

hotel_df["Hotel_Name"] = hotel_names
hotel_df
# Out:
#          City     Lat     Lng  Max_Temp Humidity  Cloudiness  Wind_Speed  \
# 6    Flinders  -34.58  150.86    295.37       46         0.0        2.68
# 214       Sur   22.57   59.53    299.39       75         0.0        2.75
# 281       Moa   20.66  -74.94    296.79       82         0.0        3.76
# 336  San Juan  -31.54  -68.54    295.27       34         0.0        3.09
#
#     Country        Date                   Hotel_Name
# 6        AU  1587182355  Shellharbour Village Escape
# 214      OM  1587182416            Arabian Sea Motel
# 281      CU  1587182441              Renta en Divisa
# 336      AR  1587182457       Departamento Hospedaje

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel_Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row

# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
hotel_df["Lat"].astype(float)
hotel_df["Lng"].astype(float)
locations = hotel_df[["Lat", "Lng"]]
locations["Lat"] = pd.to_numeric(locations["Lat"],errors="coerce")
locations["Lng"] = pd.to_numeric(locations["Lng"],errors="coerce")
location = locations.to_records(index=False)
result = list(location)
print(result)
# Out:
# [(-34.58, 150.86), (22.57, 59.53), (20.66, -74.94), (-31.54, -68.54)]
# /Users/taylorpalinkas/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/taylorpalinkas/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(result)
fig.add_layer(markers)
fig

# Display figure
# Out:
# Figure(layout=FigureLayout(height='420px'))
